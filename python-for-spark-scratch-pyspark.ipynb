# %% [markdown]
# # Python for Spark — PySpark scratchpad
#
# This scratchpad boots a Spark session so snippets like `spark.createDataFrame(...)` work. Run the two setup cells top-to-bottom (the install takes ~30s the first time), then paste snippets from the notes into the empty cell below.

# %%
# 1. Install PySpark (first run only, ~30s)
# !pip install -q pyspark

# %%
# 2. Start a Spark session -> gives you `spark`
from pyspark.sql import SparkSession
from pyspark.sql import functions as F

spark = SparkSession.builder.appName("python-for-spark").getOrCreate()
spark
